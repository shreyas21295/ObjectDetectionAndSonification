# %% [markdown]
# Below is a list of the available images that you can load:
#
# * cat.jpg
# * city_scene.jpg
# * dog.jpg
# * dog2.jpg
# * eagle.jpg
# * food.jpg
# * giraffe.jpg
# * horses.jpg
# * motorbike.jpg
# * person.jpg
# * surf.jpg
# * wine.jpg
#
# These images are located in the`./images/`folder.

# %%
pip install google.cola
# Out:
# ...
#   Using cached google_colab-1.0.0-py2.py3-none-any.whl
# ...
#   Using cached google_auth-1.4.2-py2.py3-none-any.whl (64 kB)
# ...
#   Using cached pandas-0.24.2.tar.gz (11.8 MB)
# ...
#   Using cached portpicker-1.2.0.tar.gz (17 kB)
# ...
#   Using cached tornado-4.5.3.tar.gz (484 kB)
# ...
#   Using cached notebook-5.2.2-py2.py3-none-any.whl (8.0 MB)
# ...
#   Using cached ipykernel-4.6.1-py3-none-any.whl (104 kB)
# ...
#   Using cached requests-2.21.0-py2.py3-none-any.whl (57 kB)
# ...
#   Using cached six-1.12.0-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached ipython-5.5.0-py3-none-any.whl (758 kB)
# ...
#   Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# ...
#   Using cached cachetools-4.2.4-py3-none-any.whl (10 kB)
# ...
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# ...
#   Using cached prompt_toolkit-1.0.18-py3-none-any.whl (245 kB)
# ...
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# ...
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# ...
#   Using cached idna-2.8-py2.py3-none-any.whl (58 kB)
# ...

# %%
import google
from google.colab import drive
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-95c05a260e16> in <module>
# ----> 1 import google
#       2 from google.colab import drive
#
# ModuleNotFoundError: No module named 'google'

# %%
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-837f90cc644e> in <module>
# ----> 1 drive.mount('/content/gdrive')
#
# NameError: name 'drive' is not defined

# %%
# %cd gdrive/
# Out:
# [Errno 2] No such file or directory: 'gdrive/'
# /Users/shreyas/Downloads/YOLO-Object-Detection-master

# %%
# %cd MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
# %cd YOLO-Object-Detection-master/
# Out:
# /content/gdrive/MyDrive/YOLO-Object-Detection-master

# %%
pip install cv2
# Out:
# ERROR: Could not find a version that satisfies the requirement cv2
# ERROR: No matching distribution found for cv2
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt
from utils import *
import importlib 
from darknet import Darknet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-32434e59044f> in <module>
# ----> 1 import cv2
#       2 import matplotlib.pyplot as plt
#       3 from utils import *
#       4 import importlib
#       5 from darknet import Darknet
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights

# %%
# Set the location and name of the cfg file
cfg_file = '/content/gdrive/MyDrive/YOLO-Object-Detection-master/cfg/yolov3.cfg'

# Set the location and name of the pre-trained weights file
weight_file = '/content/gdrive/MyDrive/YOLO-Object-Detection-master/weights/yolov3.weights'

# Set the location and name of the COCO object classes file
namesfile = 'data/coco.names'

# Load the network architecture
m = Darknet(cfg_file)

# Load the pre-trained weights
m.load_weights(weight_file)

# Load the COCO object classes
class_names = load_class_names(namesfile)

# %%
# Print the neural network used in YOLOv3
m.print_network()
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32
#     1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64
#     2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32
#     3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64
#     4 shortcut 1
#     5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128
#     6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64
#     7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128
#     8 shortcut 5
#     9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64
#    10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128
#    11 shortcut 8
#    12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256
#    13 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128
#    14 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256
# ...

# %%
# Set the default figure size
plt.rcParams['figure.figsize'] = [24.0, 14.0]

# Load the image
img = cv2.imread('./images/dog.jpg')

# Convert the image to RGB
original_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# We resize the image to the input width and height of the first layer of the network.    
resized_image = cv2.resize(original_image, (m.width, m.height))

# Display the images
plt.subplot(121)
plt.title('Original Image')
plt.imshow(original_image)
plt.subplot(122)
plt.title('Resized Image')
plt.imshow(resized_image)
plt.show()

# %%
# Set the NMS threshold
nms_thresh = 0.6

# %%
# Set the IOU threshold
iou_thresh = 0.4

# %%
# %load_ext autoreload
# %autoreload 2
# Set the default figure size
plt.rcParams['figure.figsize'] = [24.0, 14.0]

# Load the image
img = cv2.imread('./images/city_scene.jpg')

# Convert the image to RGB
original_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# We resize the image to the input width and height of the first layer of the network.    
resized_image = cv2.resize(original_image, (m.width, m.height))

# Set the IOU threshold. Default value is 0.4
iou_thresh = 0.4

# Set the NMS threshold. Default value is 0.6
nms_thresh = 0.6

# Detect objects in the image
boxes = detect_objects(m, resized_image, iou_thresh, nms_thresh)

# Print the objects found and the confidence level
print_objects(boxes, class_names)

#Plot the image with bounding boxes and corresponding object class labels
plot_boxes(original_image, boxes, class_names, plot_labels = True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import csv
